# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset =pd.read_csv("Superstore_USA_NEW.csv")

# %%
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code  Order Date   Ship Date  \
# 0  Central          Illinois    Addison        60101  28/05/2012  30/05/2012
# 1     West        Washington  Anacortes        98221  07/07/2010  08/07/2010
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
dataset.shape
# Out:
# (739, 24)

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     4
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(),inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9252\1305928458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(),inplace=True)

# %% [markdown]
# # Order Priority

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             175
# Medium           165
# Not Specified    139
# Critical         135
# Low              125
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Order Priority',data=dataset)
plt.title('Count of Order Priority')
plt.savefig('Count of Order Priority.jpg')
plt.show()

# %% [markdown]
# # Shipping Mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       553
# Express Air        95
# Delivery Truck     91
# Name: count, dtype: int64

# %%
x=dataset['Ship Mode'].value_counts().index
y=dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.title('Ship Mode')
plt.savefig('Ship Mode.jpg')
plt.show()

# %%
# pie velton analysis

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode",data=dataset,hue="Product Category")
plt.title(' Product category as per Ship Mode')
plt.savefig('Product category as per Ship Mode.jpg')
plt.show()

# %% [markdown]
# # Customer Segment

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment",data=dataset)
plt.title(' Customer segment ')
plt.savefig(' Customer segment.jpg')
plt.show()

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category",data=dataset)
plt.title(' Product Category ')
plt.savefig(' Product Category.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Product Category",data=dataset[dataset["Product Category"]=="Office Supplies"],hue="Product Sub-Category")
 
plt.title(' Product Category ')
plt.savefig(' Product Category.jpg')
plt.show()

# %% [markdown]
# # Profit Analysis

# %%
plt.figure(figsize=(5,3))
sns.barplot(x="Product Category",y="Profit",data=dataset,estimator='sum')
plt.title(' Profit')
plt.savefig(' Profit.jpg')
plt.show()

# %% [markdown]
# # State wise Classification

# %%
dataset["State or Province"].value_counts()
# Out:
# State or Province
# California        78
# Texas             69
# New York          65
# Illinois          63
# Oregon            44
# Washington        42
# Tennessee         37
# Utah              36
# Colorado          32
# Kansas            30
# Massachusetts     30
# Ohio              27
# North Carolina    22
# Virginia          19
# Arizona           18
# Minnesota         17
# New Jersey        14
# Pennsylvania      12
# Louisiana         11
# Montana            9
# Michigan           8
# Maine              7
# Florida            7
# Iowa               6
# Vermont            6
# Missouri           5
# Georgia            5
# New Hampshire      4
# Connecticut        4
# Nebraska           3
# Rhode Island       3
# Oklahoma           3
# New Mexico         3
# Name: count, dtype: int64

# %%
dataset["State or Province"].value_counts()[:5]
# Out:
# State or Province
# California    78
# Texas         69
# New York      65
# Illinois      63
# Oregon        44
# Name: count, dtype: int64

# %% [markdown]
# # Profit Product base

# %%
plt.figure(figsize=(5,3))
sns.barplot(x="Product Category",y="Product Base Margin",data=dataset,estimator='sum')
plt.title(' Profit Product base margin')
plt.savefig(' Profit Product base margin.jpg')  
plt.show()
